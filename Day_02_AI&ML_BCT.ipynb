# %%
#stings and its methods
text= "hello world"

print(text.upper())
print(text.lower())
print(text.title())
print(text.capitalize())
print(text.replace("world","Python"))
print(text.find("world"))
print(len(text))
# Out:
# HELLO WORLD
# hello world
# Hello World
# Hello world
# hello Python
# 6
# 11

# %%
#list and its method
numbers = [10, 20, 30]

numbers.append(40)   #at the end
print(numbers)

numbers.insert(1,15) #add at index 1
print(numbers)

numbers.remove(20)   #remove value
print(numbers)

numbers.pop()        #remove last item
print(numbers)

numbers.sort()       #sort list
print(numbers)

numbers.reverse()    # reverse list
print(numbers)
# Out:
# [10, 20, 30, 40]
# [10, 15, 20, 30, 40]
# [10, 15, 30, 40]
# [10, 15, 30]
# [10, 15, 30]
# [30, 15, 10]

# %%
#For loop
for i in range(1,6):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#For loop
for i in range(10,5,-1):
  print(i)
# Out:
# 10
# 9
# 8
# 7
# 6

# %%
#For loop
for i in range(-4,5):
  print(i)
# Out:
# -4
# -3
# -2
# -1
# 0
# 1
# 2
# 3
# 4

# %%
fruits = ["apple","banana","mango"]
for fruits in fruits:
  print(fruits)
# Out:
# apple
# banana
# mango

# %%
i = 1
while i<=5:
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 1
while i<=5:
  print("Hello")
  i+=1
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello

# %%
#nested loop

for i in range(1,4):
  for j in range(1,4):
    print(i,j)
# Out:
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
# 3 1
# 3 2
# 3 3

# %%
def greet(name):
  print("Hello", name)

greet("Alex")
greet("Alok")
greet("Aman")
# Out:
# Hello Alex
# Hello Alok
# Hello Aman

# %%
#PROJECT 1


#Smart Grade Calculator

print("---Smart Grade Calculator---")
name = input("Enter student name:")

sub1=float(input("Enter marks for Subject 1: "))
sub2=float(input("Enter marks for Subject 2: "))
sub3=float(input("Enter marks for Subject 3: "))
sub4=float(input("Enter marks for Subject 4: "))
sub5=float(input("Enter marks for Subject 5: "))

total = sub1 + sub2 + sub3 + sub4 + sub5
average = total / 5

if average >= 90:
  grade ="A+"
elif average >= 80:
  grade ="A"
elif average >= 70:
  grade ="B"
elif average >= 60:
  grade ="C"
elif average >= 50:
  grade ="D"
else:
  grade = "F"

print("\n---Result---")
print("Student Name: ", name)
print("Total Marks: ", total)
print("Average Marks: ", average)
print("Grade: ", grade)
# Out:
# ---Smart Grade Calculator---
# Enter student name:Ashim Basak
# Enter marks for Subject 1: 87
# Enter marks for Subject 2: 68
# Enter marks for Subject 3: 85
# Enter marks for Subject 4: 78
# Enter marks for Subject 5: 87
#
# ---Result---
# Student Name:  Ashim Basak
# Total Marks:  405.0
# Average Marks:  81.0
# Grade:  A

# %% [markdown]
# **Project 2 - Simple Calculator App**

# %%
#PROJECT 2


#Simple Calculator App

print("---Simple Calculator App---")

num1 = float(input("Enter First Number: "))
num2 = float(input("Enter Second Number: "))

print("\n Choose Operation: ")
print("1.Addition")
print("2.Substraction")
print("3.Multiflication")
print("4.Division")

choice = input("Enter Your Choice (1/2/3/4): ")
if choice == "1":
  print("Result =", num1+num2)
elif choice == "2":
  print("Result =", num1-num2)
elif choice == "3":
  print("Result =", num1*num2)
elif choice == "4":
  if num2 != 0:
    print("Result =", num1/num2)
  else:
    print("Division by zero is not allowed")
else:
    print("Invalid Choice Found")
# Out:
# ---Simple Calculator App---
# Enter First Number: 12
# Enter Second Number: 55
#
#  Choose Operation:
# 1.Addition
# 2.Substraction
# 3.Multiflication
# 4.Division
# Enter Your Choice (1/2/3/4): 2
# Result = -43.0

# %% [markdown]
# Project 3

# %%
#Contact Minibook Project

contacts = {}
while True:
  print("\n==Contact Book==")
  print("1.Add Contact")
  print("2.View Contact")
  print("3.Search Contact")
  print("4.Delete Contact")
  print("5.Exit")

  choice = input("Enter your Choice: ")
  if choice == "1":
    name = input("Enter Contact name: ")
    phone = input("Enter Phone number: ")
    contacts[name] = phone
    print("Contact added Successfully")
  elif choice == "2":
    if contacts:
      print("\n Saved Contacts")
      for name, phone in contacts.item():
        print(name, ":", phone)
    else:
        print("NO CONTACTS FOUND")
  elif choice == "3":
    name = input("Enter contact name to search: ")
    if name in contacts:
      print("Phone Number :", contacts[name])
    else:
      print("CONTACT NOT FOUND.")
  elif choice == "4":
    name = input("Enter contact name to delete: ")
    if name in contacts:
      del contacts[name]
      print("Contact Deleted successfully.")
    else:
      print("Contact not Found.")
  elif choice == "5":
    print("Exiting Contact Book...")
    break

  else:
    print("Invalid Choice. Please try again")
# Out:
# ==Contact Book==
# 1.Add Contact
# 2.View Contact
# 3.Search Contact
# 4.Delete Contact
# 5.Exit
# Enter your Choice: 1
# Enter Contact name: 2
# Enter Phone number: 152313
# Contact added Successfully
#
# ==Contact Book==
# 1.Add Contact
# 2.View Contact
# 3.Search Contact
# 4.Delete Contact
# 5.Exit
# Enter your Choice: 2
#
#  Saved Contacts
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_12018/3814285970.py in <cell line: 0>()
#      19     if contacts:
#      20       print("\n Saved Contacts")
# ---> 21       for name, phone in contacts.item():
#      22         print(name, ":", phone)
#      23     else:
#
# AttributeError: 'dict' object has no attribute 'item'
